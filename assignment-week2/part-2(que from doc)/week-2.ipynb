-- %%
DROP TABLE IF EXISTS order_items;
DROP TABLE IF EXISTS orders;
DROP TABLE IF EXISTS customers;
DROP TABLE IF EXISTS products;

-- %%
CREATE TABLE customers (
    customer_id  INT,
    first_name   STRING,
    last_name    STRING,
    email        STRING,
    city         STRING,
    state        STRING,
    join_date    DATE,
    is_premium   BOOLEAN
) USING DELTA;

-- %%
CREATE TABLE products (
    product_id   INT,
    product_name STRING,
    category     STRING,
    brand        STRING,
    unit_price   DECIMAL(10,2),
    stock_qty    INT
) USING DELTA;

-- %%
CREATE TABLE orders (
    order_id     INT,
    customer_id  INT,
    order_date   DATE,
    status       STRING,
    total_amount DECIMAL(12,2)
) USING DELTA;

-- %%
CREATE TABLE order_items (
    item_id      INT,
    order_id     INT,
    product_id   INT,
    quantity     INT,
    unit_price   DECIMAL(10,2),
    discount_pct DECIMAL(5,2)
) USING DELTA;

-- %%
INSERT INTO customers VALUES
(101,'Aarav','Sharma','aarav.s@email.com','Mumbai','Maharashtra','2024-01-15',true),
(102,'Priya','Patel','priya.p@email.com','Ahmedabad','Gujarat','2024-02-20',false),
(103,'Rohan','Gupta','rohan.g@email.com','Delhi','Delhi','2024-03-10',true),
(104,'Sneha','Reddy','sneha.r@email.com','Hyderabad','Telangana','2024-04-05',false),
(105,'Vikram','Singh','vikram.s@email.com','Jaipur','Rajasthan','2024-05-12',true),
(106,'Ananya','Iyer','ananya.i@email.com','Chennai','Tamil Nadu','2024-06-18',false),
(107,'Karan','Mehta','karan.m@email.com','Pune','Maharashtra','2024-07-22',true),
(108,'Divya','Nair','divya.n@email.com','Kochi','Kerala','2024-08-30',false);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>

-- %%
INSERT INTO products VALUES
(201,'Wireless Earbuds','Electronics','BoAt',1499.00,250),
(202,'Cotton T-Shirt','Clothing','Levis',799.00,500),
(203,'Smart Watch','Electronics','Noise',2999.00,150),
(204,'Running Shoes','Clothing','Nike',4599.00,120),
(205,'Bluetooth Speaker','Electronics','JBL',3499.00,200),
(206,'Bedsheet Set','Home','Spaces',1299.00,300),
(207,'Laptop Stand','Electronics','AmazonBasics',899.00,180),
(208,'Cushion Covers (Set)','Home','HomeCenter',599.00,400);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>

-- %%
INSERT INTO orders VALUES
(1001,101,'2024-08-01','Delivered',4498.00),
(1002,102,'2024-08-03','Delivered',799.00),
(1003,103,'2024-08-05','Shipped',7498.00),
(1004,101,'2024-08-10','Delivered',3499.00),
(1005,104,'2024-08-12','Cancelled',2999.00),
(1006,105,'2024-08-15','Delivered',5898.00),
(1007,106,'2024-08-18','Pending',1299.00),
(1008,103,'2024-08-20','Delivered',899.00),
(1009,107,'2024-08-25','Shipped',6098.00),
(1010,108,'2024-08-28','Delivered',1598.00);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

-- %%
INSERT INTO order_items VALUES
(5001,1001,201,2,1499.00,0),
(5002,1001,207,1,899.00,10),
(5003,1002,202,1,799.00,0),
(5004,1003,203,1,2999.00,0),
(5005,1003,204,1,4599.00,5),
(5006,1004,205,1,3499.00,0),
(5007,1005,203,1,2999.00,0),
(5008,1006,201,1,1499.00,10),
(5009,1006,204,1,4599.00,5),
(5010,1007,206,1,1299.00,0),
(5011,1008,207,1,899.00,0),
(5012,1009,205,1,3499.00,0),
(5013,1009,208,2,599.00,15),
(5014,1010,206,1,1299.00,0),
(5015,1010,208,1,599.00,0);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>15</td><td>15</td></tr></tbody></table></div>

-- %%
SELECT 'customers'  AS tbl, COUNT(*) AS rows FROM customers  UNION ALL
SELECT 'products',          COUNT(*)          FROM products   UNION ALL
SELECT 'orders',            COUNT(*)          FROM orders     UNION ALL
SELECT 'order_items',       COUNT(*)          FROM order_items;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tbl</th><th>rows</th></tr></thead><tbody><tr><td>customers</td><td>8</td></tr><tr><td>products</td><td>8</td></tr><tr><td>orders</td><td>10</td></tr><tr><td>order_items</td><td>15</td></tr></tbody></table></div>

-- %% [markdown]
-- Section A

-- %% [markdown]
-- Q1

-- %%
SELECT * FROM customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>last_name</th><th>email</th><th>city</th><th>state</th><th>join_date</th><th>is_premium</th></tr></thead><tbody><tr><td>101</td><td>Aarav</td><td>Sharma</td><td>aarav.s@email.com</td><td>Mumbai</td><td>Maharashtra</td><td>2024-01-15</td><td>true</td></tr><tr><td>102</td><td>Priya</td><td>Patel</td><td>priya.p@email.com</td><td>Ahmedabad</td><td>Gujarat</td><td>2024-02-20</td><td>false</td></tr><tr><td>103</td><td>Rohan</td><td>Gupta</td><td>rohan.g@email.com</td><td>Delhi</td><td>Delhi</td><td>2024-03-10</td><td>true</td></tr><tr><td>104</td><td>Sneha</td><td>Reddy</td><td>sneha.r@email.com</td><td>Hyderabad</td><td>Telangana</td><td>2024-04-05</td><td>false</td></tr><tr><td>105</td><td>Vikram</td><td>Singh</td><td>vikram.s@email.com</td><td>Jaipur</td><td>Rajasthan</td><td>2024-05-12</td><td>true</td></tr><tr><td>106</td><td>Ananya</td><td>Iyer</td><td>ananya.i@email.com</td><td>Chennai</td><td>Tamil Nadu</td><td>2024-06-18</td><td>false</td></tr><tr><td>107</td><td>Karan</td><td>Mehta</td><td>karan.m@email.com</td><td>Pune</td><td>Maharashtra</td><td>2024-07-22</td><td>true</td></tr><tr><td>108</td><td>Divya</td><td>Nair</td><td>divya.n@email.com</td><td>Kochi</td><td>Kerala</td><td>2024-08-30</td><td>false</td></tr></tbody></table></div>

-- %% [markdown]
-- Q2

-- %%
select first_name,last_name,city from customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>city</th></tr></thead><tbody><tr><td>Aarav</td><td>Sharma</td><td>Mumbai</td></tr><tr><td>Priya</td><td>Patel</td><td>Ahmedabad</td></tr><tr><td>Rohan</td><td>Gupta</td><td>Delhi</td></tr><tr><td>Sneha</td><td>Reddy</td><td>Hyderabad</td></tr><tr><td>Vikram</td><td>Singh</td><td>Jaipur</td></tr><tr><td>Ananya</td><td>Iyer</td><td>Chennai</td></tr><tr><td>Karan</td><td>Mehta</td><td>Pune</td></tr><tr><td>Divya</td><td>Nair</td><td>Kochi</td></tr></tbody></table></div>

-- %% [markdown]
-- Q3

-- %%
select distinct category from products order by category;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th></tr></thead><tbody><tr><td>Clothing</td></tr><tr><td>Electronics</td></tr><tr><td>Home</td></tr></tbody></table></div>

-- %% [markdown]
-- Q4

-- %%
-- Primary Keys:
-- customers  → customer_id
-- products   → product_id
-- orders     → order_id
-- order_items → item_id
--
-- A Primary Key must be UNIQUE so every row can be individually identified.
-- It must be NOT NULL because NULL means "unknown" — you cannot identify
-- a row with an unknown value. Together they guarantee every row has
-- a stable, unambiguous identity.

-- %% [markdown]
-- Q5

-- %%
INSERT INTO customers VALUES (109,'Test','User','aarav.s@email.com','Delhi','Delhi','2024-09-01',false);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %% [markdown]
-- Q6

-- %%
SELECT product_name, unit_price FROM products WHERE unit_price > 0;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_name</th><th>unit_price</th></tr></thead><tbody><tr><td>Wireless Earbuds</td><td>1499.00</td></tr><tr><td>Cotton T-Shirt</td><td>799.00</td></tr><tr><td>Smart Watch</td><td>2999.00</td></tr><tr><td>Running Shoes</td><td>4599.00</td></tr><tr><td>Bluetooth Speaker</td><td>3499.00</td></tr><tr><td>Bedsheet Set</td><td>1299.00</td></tr><tr><td>Laptop Stand</td><td>899.00</td></tr><tr><td>Cushion Covers (Set)</td><td>599.00</td></tr></tbody></table></div>

-- %% [markdown]
-- Section-B

-- %% [markdown]
-- Q7

-- %%
SELECT * FROM orders WHERE status = 'Delivered';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>order_date</th><th>status</th><th>total_amount</th></tr></thead><tbody><tr><td>1001</td><td>101</td><td>2024-08-01</td><td>Delivered</td><td>4498.00</td></tr><tr><td>1002</td><td>102</td><td>2024-08-03</td><td>Delivered</td><td>799.00</td></tr><tr><td>1004</td><td>101</td><td>2024-08-10</td><td>Delivered</td><td>3499.00</td></tr><tr><td>1006</td><td>105</td><td>2024-08-15</td><td>Delivered</td><td>5898.00</td></tr><tr><td>1008</td><td>103</td><td>2024-08-20</td><td>Delivered</td><td>899.00</td></tr><tr><td>1010</td><td>108</td><td>2024-08-28</td><td>Delivered</td><td>1598.00</td></tr></tbody></table></div>

-- %% [markdown]
-- Q8

-- %%
SELECT product_id, product_name, brand, unit_price
FROM products
WHERE category = 'Electronics'
  AND unit_price > 2000
ORDER BY unit_price DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>brand</th><th>unit_price</th></tr></thead><tbody><tr><td>205</td><td>Bluetooth Speaker</td><td>JBL</td><td>3499.00</td></tr><tr><td>203</td><td>Smart Watch</td><td>Noise</td><td>2999.00</td></tr></tbody></table></div>

-- %% [markdown]
-- Q9

-- %%
SELECT customer_id, first_name, last_name, city, join_date
FROM customers
WHERE state = 'Maharashtra'
  AND join_date >= '2024-01-01'
  AND join_date <  '2025-01-01'
ORDER BY join_date;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>last_name</th><th>city</th><th>join_date</th></tr></thead><tbody><tr><td>101</td><td>Aarav</td><td>Sharma</td><td>Mumbai</td><td>2024-01-15</td></tr><tr><td>107</td><td>Karan</td><td>Mehta</td><td>Pune</td><td>2024-07-22</td></tr></tbody></table></div>

-- %% [markdown]
-- Q10

-- %%
SELECT order_id, customer_id, order_date, status, total_amount
FROM orders
WHERE order_date BETWEEN '2024-08-10' AND '2024-08-25'
  AND status <> 'Cancelled'
ORDER BY order_date;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>order_date</th><th
td>false</td></tr></tbody></table></div>

-- %% [markdown]
-- Section C

-- %% [markdown]
-- Q13

-- %%
SELECT COUNT(*) AS total_orders FROM orders;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_orders</th></tr></thead><tbody><tr><td>10</td></tr></tbody></table></div>

-- %% [markdown]
-- Q14

-- %%
SELECT SUM(total_amount) AS delivered_revenue
FROM orders
WHERE status = 'Delivered';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>delivered_revenue</th></tr></thead><tbody><tr><td>17191.00</td></tr></tbody></table></div>

-- %% [markdown]
-- Q15

-- %%
SELECT category, ROUND(AVG(unit_price), 2) AS avg_unit_price
FROM products
GROUP BY category
ORDER BY avg_unit_price DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>avg_unit_price</th></tr></thead><tbody><tr><td>Clothing</td><td>2699.00</td></tr><tr><td>Electronics</td><td>2224.00</td></tr><tr><td>Home</td><td>949.00</td></tr></tbody></table></div>

-- %% [markdown]
-- Q16

-- %%
SELECT status,
       COUNT(*)          AS order_count,
       SUM(total_amount) AS total_revenue
FROM orders
GROUP BY status
ORDER BY total_revenue DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>status</th><th>order_count</th><th>total_revenue</th></tr></thead><tbody><tr><td>Delivered</td><td>6</td><td>17191.00</td></tr><tr><td>Shipped</td><td>2</td><td>13596.00</td></tr><tr><td>Cancelled</td><td>1</td><td>2999.00</td></tr><tr><td>Pending</td><td>1</td><td>1299.00</td></tr></tbody></table></div>

-- %% [markdown]
-- Q17

-- %%
SELECT category,
       MAX(unit_price) AS most_expensive,
       MIN(unit_price) AS cheapest
FROM products
GROUP BY category
ORDER BY category;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>most_expensive</th><th>cheapest</th></tr></thead><tbody><tr><td>Clothing</td><td>4599.00</td><td>799.00</td></tr><tr><td>Electronics</td><td>3499.00</td><td>899.00</td></tr><tr><td>Home</td><td>1299.00</td><td>599.00</td></tr></tbody></table></div>

-- %% [markdown]
-- Q18

-- %%
SELECT category,
       ROUND(AVG(unit_price), 2) AS avg_price
FROM products
GROUP BY category
HAVING AVG(unit_price) > 2000
ORDER BY avg_price DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>avg_price</th></tr></thead><tbody><tr><td>Clothing</td><td>2699.00</td></tr><tr><td>Electronics</td><td>2224.00</td></tr></tbody></table></div>

-- %% [markdown]
-- Section D

-- %% [markdown]
-- Q19

-- %%
SELECT o.order_id, o.order_date,
       c.first_name, c.last_name,
       o.total_amount
FROM orders o
INNER JOIN customers c ON o.customer_id = c.customer_id
ORDER BY o.order_date;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th><th>first_name</th><th>last_name</th><th>total_amount</th></tr></thead><tbody><tr><td>1001</td><td>2024-08-01</td><td>Aarav</td><td>Sharma</td><td>4498.00</td></tr><tr><td>1002</td><td>2024-08-03</td><td>Priya</td><td>Patel</td><td>799.00</td></tr><tr><td>1003</td><td>2024-08-05</td><td>Rohan</td><td>Gupta</td><td>7498.00</td></tr><tr><td>1004</td><td>2024-08-10</td><td>Aarav</td><td>Sharma</td><td>3499.00</td></tr><tr><td>1005</td><td>2024-08-12</td><td>Sneha</td><td>Reddy</td><td>2999.00</td></tr><tr><td>1006</td><td>2024-08-15</td><td>Vikram</td><td>Singh</td><td>5898.00</td></tr><tr><td>1007</td><td>2024-08-18</td><td>Ananya</td><td>Iyer</td><td>1299.00</td></tr><tr><td>1008</td><td>2024-08-20</td><td>Rohan</td><td>Gupta</td><td>899.00</td></tr><tr><td>1009</td><td>2024-08-25</td><td>Karan</td><td>Mehta</td><td>6098.00</td></tr><tr><td>1010</td><td>2024-08-28</td><td>Divya</td><td>Nair</td><td>1598.00</td></tr></tbody></table></div>

-- %% [markdown]
-- Q20

-- %%
SELECT c.customer_id, c.first_name, c.last_name, c.city,
       o.order_id, o.order_date, o.status, o.total_amount
FROM customers c
LEFT JOIN orders o ON c.customer_id = o.customer_id
ORDER BY c.customer_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>last_name</th><th>city</th><th>order_id</th><th>order_date</th><th>status</th><th>total_amount</th></tr></thead><tbody><tr><td>101</td><td>Aarav</td><td>Sharma</td><td>Mumbai</td><td>1004</td><td>2024-08-10</td><td>Delivered</td><td>3499.00</td></tr><tr><td>101</td><td>Aarav</td><td>Sharma</td><td>Mumbai</td><td>1001</td><td>2024-08-01</td><td>Delivered</td><td>4498.00</td></tr><tr><td>102</td><td>Priya</td><td>Patel</td><td>Ahmedabad</td><td>1002</td><td>2024-08-03</td><td>Delivered</td><td>799.00</td></tr><tr><td>103</td><td>Rohan</td><td>Gupta</td><td>Delhi</td><td>1008</td><td>2024-08-20</td><td>Delivered</td><td>899.00</td></tr><tr><td>103</td><td>Rohan</td><td>Gupta</td><td>Delhi</td><td>1003</td><td>2024-08-05</td><td>Shipped</td><td>7498.00</td></tr><tr><td>104</td><td>Sneha</td><td>Reddy</td><td>Hyderabad</td><td>1005</td><td>2024-08-12</td><td>Cancelled</td><td>2999.00</td></tr><tr><td>105</td><td>Vikram</td><td>Singh</td><td>Jaipur</td><td>1006</td><td>2024-08-15</td><td>Delivered</td><td>5898.00</td></tr><tr><td>106</td><td>Ananya</td><td>Iyer</td><td>Chennai</td><td>1007</td><td>2024-08-18</td><td>Pending</td><td>1299.00</td></tr><tr><td>107</td><td>Karan</td><td>Mehta</td><td>Pune</td><td>1009</td><td>2024-08-25</td><td>Shipped</td><td>6098.00</td></tr><tr><td>108</td><td>Divya</td><td>Nair</td><td>Kochi</td><td>1010</td><td>2024-08-28</td><td>Delivered</td><td>1598.00</td></tr><tr><td>109</td><td>Test</td><td>User</td><td>Delhi</td><td>null</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- Q21

-- %%
SELECT o.order_id,
       p.product_name,
       oi.quantity,
       oi.unit_price,
       oi.discount_pct,
       ROUND(oi.unit_price * oi.quantity * (1 - oi.discount_pct / 100), 2) AS line_total
FROM orders o
JOIN order_items oi ON o.order_id   = oi.order_id
JOIN products   p  ON oi.product_id = p.product_id
ORDER BY o.order_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product
</td><td>Bedsheet Set</td><td>1</td><td>1299.00</td><td>0.00</td><td>1299.00</td></tr><tr><td>1008</td><td>Laptop Stand</td><td>1</td><td>899.00</td><td>0.00</td><td>899.00</td></tr><tr><td>1009</td><td>Bluetooth Speaker</td><td>1</td><td>3499.00</td><td>0.00</td><td>3499.00</td></tr><tr><td>1009</td><td>Cushion Covers (Set)</td><td>2</td><td>599.00</td><td>15.00</td><td>1018.30</td></tr><tr><td>1010</td><td>Bedsheet Set</td><td>1</td><td>1299.00</td><td>0.00</td><td>1299.00</td></tr><tr><td>1010</td><td>Cushion Covers (Set)</td><td>1</td><td>599.00</td><td>0.00</td><td>599.00</td></tr></tbody></table></div>

-- %% [markdown]
-- Q22

-- %%
SELECT c.customer_id, c.first_name, o.order_id
FROM customers c
LEFT JOIN orders o ON c.customer_id = o.customer_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>order_id</th></tr></thead><tbody><tr><td>101</td><td>Aarav</td><td>1004</td></tr><tr><td>102</td><td>Priya</td><td>1002</td></tr><tr><td>103</td><td>Rohan</td><td>1008</td></tr><tr><td>104</td><td>Sneha</td><td>1005</td></tr><tr><td>105</td><td>Vikram</td><td>1006</td></tr><tr><td>106</td><td>Ananya</td><td>1007</td></tr><tr><td>107</td><td>Karan</td><td>1009</td></tr><tr><td>108</td><td>Divya</td><td>1010</td></tr><tr><td>101</td><td>Aarav</td><td>1001</td></tr><tr><td>103</td><td>Rohan</td><td>1003</td></tr><tr><td>109</td><td>Test</td><td>null</td></tr></tbody></table></div>

-- %%
SELECT c.customer_id, c.first_name, o.order_id
FROM customers c
FULL OUTER JOIN orders o ON c.customer_id = o.customer_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>order_id</th></tr></thead><tbody><tr><td>105</td><td>Vikram</td><td>1006</td></tr><tr><td>104</td><td>Sneha</td><td>1005</td></tr><tr><td>108</td><td>Divya</td><td>1010</td></tr><tr><td>106</td><td>Ananya</td><td>1007</td></tr><tr><td>103</td><td>Rohan</td><td>1008</td></tr><tr><td>107</td><td>Karan</td><td>1009</td></tr><tr><td>102</td><td>Priya</td><td>1002</td></tr><tr><td>101</td><td>Aarav</td><td>1004</td></tr><tr><td>109</td><td>Test</td><td>null</td></tr><tr><td>103</td><td>Rohan</td><td>1003</td></tr><tr><td>101</td><td>Aarav</td><td>1001</td></tr></tbody></table></div>

-- %% [markdown]
-- Q23

-- %%
SELECT o.order_id, o.customer_id, c.first_name
FROM orders o
JOIN customers c ON o.customer_id = c.customer_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>first_name</th></tr></thead><tbody><tr><td>1004</td><td>101</td><td>Aarav</td></tr><tr><td>1002</td><td>102</td><td>Priya</td></tr><tr><td>1008</td><td>103</td><td>Rohan</td></tr><tr><td>1005</td><td>104</td><td>Sneha</td></tr><tr><td>1006</td><td>105</td><td>Vikram</td></tr><tr><td>1007</td><td>106</td><td>Ananya</td></tr><tr><td>1009</td><td>107</td><td>Karan</td></tr><tr><td>1010</td><td>108</td><td>Divya</td></tr><tr><td>1001</td><td>101</td><td>Aarav</td></tr><tr><td>1003</td><td>103</td><td>Rohan</td></tr></tbody></table></div>

-- %% [markdown]
-- Section E

-- %% [markdown]
-- Q24

-- %%
SELECT product_name,
       unit_price,
       CASE
           WHEN unit_price < 1000                THEN 'Budget'
           WHEN unit_price BETWEEN 1000 AND 3000 THEN 'Mid-Range'
           ELSE                                       'Premium'
       END AS price_tier
FROM products
ORDER BY unit_price;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_name</th><th>unit_price</th><th>price_tier</th></tr></thead><tbody><tr><td>Cushion Covers (Set)</td><td>599.00</td><td>Budget</td></tr><tr><td>Cotton T-Shirt</td><td>799.00</td><td>Budget</td></tr><tr><td>Laptop Stand</td><td>899.00</td><td>Budget</td></tr><tr><td>Bedsheet Set</td><td>1299.00</td><td>Mid-Range</td></tr><tr><td>Wireless Earbuds</td><td>1499.00</td><td>Mid-Range</td></tr><tr><td>Smart Watch</td><td>2999.00</td><td>Mid-Range</td></tr><tr><td>Bluetooth Speaker</td><td>3499.00</td><td>Premium</td></tr><tr><td>Running Shoes</td><td>4599.00</td><td>Premium</td></tr></tbody></table></div>

-- %% [markdown]
-- Q25

-- %%
SELECT
    SUM(CASE WHEN status = 'Delivered'  THEN 1 ELSE 0 END) AS delivered_count,
    SUM(CASE WHEN status <> 'Delivered' THEN 1 ELSE 0 END) AS not_delivered_count
FROM orders;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>delivered_count</th><th>not_delivered_count</th></tr></thead><tbody><tr><td>6</td><td>4</td></tr></tbody></table></div>

-- %% [markdown]
-- Q26

-- %%
-- ACID Properties:
-- A - Atomicity:   All steps in a transaction succeed or ALL are rolled back.
--                  Bank transfer: if debit succeeds but credit fails → money vanishes.
--                  Atomicity ensures BOTH happen or NEITHER does.
--
-- C - Consistency: DB moves from one valid state to another. Rules always enforced.
--                  Total money before transfer = total money after transfer.
--
-- I - Isolation:   Concurrent transactions don't interfere with each other.
--                  Two clerks updating the same account see consistent balances.
--
-- D - Durability:  Once COMMITted, changes survive crashes/power cuts.
--                  Your confirmed bank transfer won't disappear after a reboot.
SELECT 'See comment above for ACID explanation' AS answer;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>answer</th></tr></thead><tbody><tr><td>See comment above for ACID explanation</td></tr></tbody></table></div>

-- %% [markdown]
-- Q27

-- %%
INSERT INTO orders VALUES (1011, 102, CURRENT_DATE, 'Pending', 1598.00);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
INSERT INTO order_items VALUES (5016, 1011, 206, 1, 1299.00, 0);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
INSERT INTO order_items VALUES (5017, 1011, 208, 1, 599.00, 0);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
UPDATE products SET stock_qty = stock_qty - 1 WHERE product_id = 206;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
UPDATE products SET stock_qty = stock_qty - 1 WHERE product_id = 208;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
SELECT o.order_id, o.status, oi.product_id, oi.quantity, p.stock_qty
FROM orders o
JOIN order_items oi ON o.order_id   = oi.order_id
JOIN products   p  ON oi.product_id = p.product_id
WHERE o.order_id = 1011;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>status</th><th>product_id</th><th>quantity</th><th>stock_qty</th></tr></thead><tbody><tr><td>1011</td><td>Pending</td><td>208</td><td>1</td><td>399</td></tr><tr><td>1011</td><td>Pending</td><td>206</td><td>1</td><td>299</td></tr></tbody></table></div>
